# %%
https://na1.api.riotgames.com/lol/static-data/v3/champions?locale=en_US&dataById=false&api_key=RGAPI-3c800bde-10ac-4354-bc8b-83e3a70e7202

# %%
import json
import csv
import urllib2
from urllib2 import Request, urlopen
import pandas as pd
import numpy as np
import unicodedata

# %%
request = Request("https://na1.api.riotgames.com/lol/static-data/v3/champions?locale=en_US&dataById=false&api_key=RGAPI-3c800bde-10ac-4354-bc8b-83e3a70e7202")
response = urlopen(request)
data = response.read()
staticData = json.loads(data)
staticData
# Out:
# {u'data': {u'Aatrox': {u'id': 266,
#    u'key': u'Aatrox',
#    u'name': u'Aatrox',
#    u'title': u'the Darkin Blade'},
#   u'Ahri': {u'id': 103,
#    u'key': u'Ahri',
#    u'name': u'Ahri',
#    u'title': u'the Nine-Tailed Fox'},
#   u'Akali': {u'id': 84,
#    u'key': u'Akali',
#    u'name': u'Akali',
#    u'title': u'the Fist of Shadow'},
#   u'Alistar': {u'id': 12,
#    u'key': u'Alistar',
#    u'name': u'Alistar',
#    u'title': u'the Minotaur'},
#   u'Amumu': {u'id': 32,
#    u'key': u'Amumu',
#    u'name': u'Amumu',
#    u'title': u'the Sad Mummy'},
#   u'Anivia': {u'id': 34,
#    u'key': u'Anivia',
#    u'name': u'Anivia',
#    u'title': u'the Cryophoenix'},
#   u'Annie': {u'id': 1,
#    u'key': u'Annie',
#    u'name': u'Annie',
#    u'title': u'the Dark Child'},
#   u'Ashe': {u'id': 22,
#    u'key': u'Ashe',
#    u'name': u'Ashe',
#    u'title': u'the Frost Archer'},
#   u'AurelionSol': {u'id': 136,
#    u'key': u'AurelionSol',
#    u'name': u'Aurelion Sol',
# ...

# %%
ChampName = []


for title in staticData['data']:
    ChampName.append(title)

print ChampName
# Out:
# [u'MonkeyKing', u'Jax', u'Fiddlesticks', u'Shaco', u'Warwick', u'Xayah', u'Nidalee', u'Zyra', u'Kled', u'Brand', u'Rammus', u'Illaoi', u'Corki', u'Braum', u'Darius', u'Tryndamere', u'MissFortune', u'Yorick', u'Xerath', u'Sivir', u'Riven', u'Orianna', u'Gangplank', u'Malphite', u'Poppy', u'Karthus', u'Jayce', u'Nunu', u'Trundle', u'Graves', u'Morgana', u'Gnar', u'Lux', u'Shyvana', u'Renekton', u'Fiora', u'Jinx', u'Kalista', u'Fizz', u'Kassadin', u'Sona', u'Irelia', u'Viktor', u'Rakan', u'Kindred', u'Cassiopeia', u'Maokai', u'Ornn', u'Thresh', u'Kayle', u'Hecarim', u'Khazix', u'Olaf', u'Ziggs', u'Syndra', u'DrMundo', u'Karma', u'Annie', u'Akali', u'Volibear', u'Yasuo', u'Kennen', u'Rengar', u'Ryze', u'Shen', u'Zac', u'Talon', u'Swain', u'Bard', u'Sion', u'Vayne', u'Nasus', u'Kayn', u'TwistedFate', u'Chogath', u'Udyr', u'Lucian', u'Ivern', u'Leona', u'Caitlyn', u'Sejuani', u'Nocturne', u'Zilean', u'Azir', u'Rumble', u'Taliyah', u'Teemo', u'Urgot', u'Amumu', u'Galio', u'Heimerdinger', u'
# ...
